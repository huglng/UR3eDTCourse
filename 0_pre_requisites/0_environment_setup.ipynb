# %% [markdown]
# # Creation of a virtual environment

# %% [markdown]
# To separate the dependencies of this project from global dependencies, we suggest creating a fresh virtual environment. Some of the needed packages require a specific version of some libraries, and this can cause conflicts with other projects.
#
# This guide will show you how to create a virtual environment using anaconda, but you can use any other tool of your preference.

# %% [markdown]
# If you do not have anaconda installed, you can download it [here](https://docs.anaconda.com/anaconda/install/).
#
# **Important:** To make conda commands available from anywere, you need to add the conda path to the system environment variables. You do this by adding anaconda to the system PATH. You can find the instructions [here](https://www.geeksforgeeks.org/how-to-setup-anaconda-path-to-environment-variable/).

# %% [markdown]
# After installing Anaconda or Miniconda, to create a virtual environment, run the following command in your terminal, replacing `<env_name>` with the name you want to give to your environment:
#
# ```bash
# conda create --name <env_name> python=3.11
# ```
#
# After creating the environment, you can activate it by running:
#
# ```bash
# conda activate <env_name>
# ```
#
# After activating the environment, your terminal should look something like this:
#
# ```bash
# (<env_name>) user@computer:~$
# ```
#
# This will allow you to install the dependencies of this project without interfering with the dependencies of other projects.
#
# To deactivate the environment, you can run:
#
# ```bash
# conda deactivate
# ```

# %% [markdown]
# # Installation of packages

# %% [markdown]
# Start by installing pip, which is the package manager for Python. You can do this by running:
#
# ```bash
# conda install pip
# ```
#
# To ease dependency management, we use [poetry](https://github.com/python-poetry/poetry) as the package manager for this project. You can install poetry by running:
#
# ```bash
# pip install poetry
# ```
#
# After installing poetry, you can install the dependencies of this project by navigating to the root folder of the project (where the `pyproject.toml` file is located) and running:
#
# ```bash
# poetry install
# ```

# %%
# !poetry install
# Out:
# Installing dependencies from lock file
#
# Package operations: 93 installs, 32 updates, 0 removals
#
#   - Installing ansitable (0.11.4)
#   - Installing argon2-cffi (25.1.0)
#   - Installing argon2-cffi-bindings (25.1.0)
#   - Installing arrow (1.4.0)
#   - Updating asttokens (3.0.1 /home/conda/feedstock_root/build_artifacts/asttokens_1763409923949/work -> 3.0.1)
#   - Installing async-lru (2.0.5)
#   - Installing attrs (25.4.0)
#   - Installing babel (2.17.0)
#   - Installing backcall (0.2.0)
#   - Installing beautifulsoup4 (4.14.3)
#   - Installing bleach (6.3.0)
#   - Installing cffi (2.0.0)
#   - Installing cfgv (3.5.0)
#   - Updating colorama (0.4.6 /home/conda/feedstock_root/build_artifacts/colorama_1733218098505/work -> 0.4.6)
#   - Installing colored (2.3.1)
#   - Updating comm (0.2.3 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_comm_1753453984/work -> 0.2.3)
#   - Installing contourpy (1.3.2)
#   - Installing coverage (7.13.1)
#   - Installing cycler (0.12.1)
#   - Downgrading debugpy (1.8.20 D:/bld/bld/rattler-build_debugpy_1769745017/work -> 1.8.19)
#   - Updating decorator (5.2.1 /home/conda/feedstock_root/build_artifacts/decorator_1740384970518/work -> 5.2.1)
#   - Installing defusedxml (0.7.1)
#   - Installing docker (7.1.0)
#   - Updating executing (2.2.1 /home/conda/feedstock_root/build_artifacts/executing_1756729339227/work -> 2.2.1)
#   - Downgrading filelock (3.24.3 -> 3.20.3)
#   - Installing fonttools (4.61.1)
#   - Installing fqdn (1.5.1)
#   - Installing identify (2.6.15)
#   - Installing iniconfig (2.3.0)
#   - Downgrading ipykernel (7.2.0 D:/bld/bld/rattler-build_ipykernel_1770566174/work -> 7.1.0)
#   - Downgrading ipython (9.10.0 D:/bld/bld/rattler-build_ipython_1770040952/work -> 8.12.3)
#   - Installing ipywidgets (8.1.8)
#   - Installing isoduration (20.11.0)
#   - Updating jedi (0.19.2 /home/conda/feedstock_root/build_artifacts/jedi_1733300866624/work -> 0.19.2)
#   - Installing jinja2 (3.1.6)
#   - Installing json5 (0.13.0)
#   - Installing jsonpointer (3.0.0)
#   - Installing jsonschema (4.26.0)
#   - Installing jsonschema-specifications (2025.9.1)
#   - Installing jupyter (1.1.1)
#   - Updating jupyter-client (8.8.0 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_jupyter_client_1767954655/work -> 8.8.0)
#   - Installing jupyter-console (6.6.3)
#   - Updating jupyter-core (5.9.1 D:/bld/bld/rattler-build_jupyter_core_1760643889/work -> 5.9.1)
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-lsp (2.3.0)
#   - Installing jupyter-server (2.17.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing jupyterlab (4.5.1)
#   - Installing jupyterlab-pygments (0.3.0)
#   - Installing jupyterlab-server (2.28.0)
#   - Installing jupyterlab-widgets (3.0.16)
#   - Installing kiwisolver (1.4.9)
#   - Installing lark (1.3.1)
#   - Installing markupsafe (3.0.3)
#   - Installing matplotlib (3.10.8)
#   - Updating matplotlib-inline (0.2.1 /home/conda/feedstock_root/build_artifacts/matplotlib-inline_1761214490209/work -> 0.2.1)
#   - Installing mistune (3.2.0)
#   - Installing nbclient (0.10.4)
#   - Installing nbconvert (7.16.6)
#   - Installing nbformat (5.10.4)
#   - Updating nest-asyncio (1.6.0 /home/conda/feedstock_root/build_artifacts/nest-asyncio_1733325553580/work -> 1.6.0)
#   - Installing nodeenv (1.10.0)
#   - Installing notebook (7.5.1)
#   - Installing notebook-shim (0.2.4)
#   - Installing numpy (1.26.4)
#   - Installing overrides (7.7.0)
#   - Updating packaging (25.0 C:/miniconda3/conda-bld/packaging_1761049096285/work -> 25.0)
#   - Installing pandas (2.3.3)
#   - Installing pandocfilters (1.5.1)
#   - Downgrading parso (0.8.6 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_parso_1770676243/work -> 0.8.5)
#   - Installing pgraph-python (0.6.3)
#   - Installing pickleshare (0.7.5)
#   - Installing pika (1.3.2)
#   - Installing pillow (12.1.0)
#   - Downgrading platformdirs (4.9.2 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_platformdirs_1771233827/work -> 4.5.1)
#   - Installing pluggy (1.6.0)
#   - Installing pre-commit (4.5.1)
#   - Installing progress (1.6.1)
#   - Installing prometheus-client (0.23.1)
#   - Updating prompt-toolkit (3.0.52 /home/conda/feedstock_root/build_artifacts/prompt-toolkit_1756321756983/work -> 3.0.52)
#   - Downgrading psutil (7.2.2 D:/bld/bld/rattler-build_psutil_1769678166/work -> 7.2.1)
#   - Updating pure-eval (0.2.3 /home/conda/feedstock_root/build_artifacts/pure_eval_1733569405015/work -> 0.2.3)
#   - Installing pycparser (2.23)
#   - Updating pygments (2.19.2 /home/conda/feedstock_root/build_artifacts/pygments_1750615794071/work -> 2.19.2)
#   - Installing pyhocon (0.3.61)
#   - Installing pyparsing (3.3.1)
#   - Installing pytest (7.4.4)
#   - Installing pytest-cov (4.1.0)
#   - Updating python-dateutil (2.9.0.post0 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_python-dateutil_1751104122/work -> 2.9.0.post0)
#   - Installing python-json-logger (4.0.0)
#   - Installing pytz (2025.2)
#   - Updating pywin32 (311 D:/bld/bld/rattler-build_pywin32_1756487145/work -> 311)
#   - Installing pywinpty (3.0.2)
#   - Installing pyyaml (6.0.3)
#   - Updating pyzmq (27.1.0 D:/bld/bld/rattler-build_pyzmq_1771716977/work -> 27.1.0)
#   - Installing referencing (0.37.0)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Installing rfc3987-syntax (1.1.0)
#   - Installing roboticstoolbox-python (1.1.1)
#   - Installing rpds-py (0.30.0)
#   - Installing rtb-data (1.0.1)
#   - Installing scipy (1.15.3)
#   - Installing send2trash (2.0.0)
#   - Downgrading setuptools (80.10.2 -> 80.9.0)
#   - Updating six (1.17.0 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_six_1753199211/work -> 1.17.0)
#   - Installing soupsieve (2.8.1)
#   - Installing spatialgeometry (1.1.0)
#   - Installing spatialmath-python (1.1.15)
#   - Updating stack-data (0.6.3 /home/conda/feedstock_root/build_artifacts/stack_data_1733569443808/work -> 0.6.3)
#   - Installing swift-sim (1.1.0)
#   - Installing terminado (0.18.1)
#   - Installing tinycss2 (1.4.0)
#   - Updating tornado (6.5.4 D:/bld/tornado_1765836389475/work -> 6.5.4)
#   - Updating traitlets (5.14.3 /home/conda/feedstock_root/build_artifacts/traitlets_1733367359838/work -> 5.14.3)
#   - Updating typing-extensions (4.15.0 /home/conda/feedstock_root/build_artifacts/bld/rattler-build_typing_extensions_1756220668/work -> 4.15.0)
#   - Installing tzdata (2025.3)
#   - Installing uri-template (1.3.0)
#   - Downgrading virtualenv (20.39.0 -> 20.36.1)
#   - Downgrading wcwidth (0.6.0 /home/conda/feedstock_root/build_artifacts/wcwidth_1770634525285/work -> 0.2.14)
#   - Installing webcolors (25.10.0)
#   - Installing webencodings (0.5.1)
#   - Installing websocket-client (1.9.0)
#   - Installing websockets (10.4)
#   - Installing widgetsnbextension (4.0.15)
#
# PEP517 build of a dependency failed
#
# Backend subprocess exited when trying to invoke build_wheel
#
#     | Command '['C:\\Users\\hugol\\AppData\\Local\\Temp\\tmpzb481vtf\\.venv\\Scripts\\python.exe', 'C:\\Users\\hugol\\miniconda3\\envs\\python311\\Lib\\site-packages\\pyproject_hooks\\_in_process\\_in_process.py', 'build_wheel', 'C:\\Users\\hugol\\AppData\\Local\\Temp\\tmpi4yevr_b']' returned non-zero exit status 1.
#     |
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#     |
#
#     |         By 2027-Feb-18, you need to update your project and remove deprecated calls
#
#     |         or your builds will no longer be supported.
#
#     |
#
#     |         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   corresp(dist, value, root_dir)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#     |
#
#     |         License :: OSI Approved :: MIT License
#
#     |
#
#     |         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   dist._finalize_license_expression()
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#     |
#
#     |         License :: OSI Approved :: MIT License
#
#     |
#
#     |         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   self._finalize_license_expression()
#
#     | running bdist_wheel
#
#     | running build
#
#     | running build_py
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox
#
#     | copying roboticstoolbox\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\backends
#
#     | copying roboticstoolbox\backends\Connector.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends
#
#     | copying roboticstoolbox\backends\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\EllipsePlot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\PyPlot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\PyPlot2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\RobotPlot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\RobotPlot2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\test1.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\test2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | copying roboticstoolbox\backends\PyPlot\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\PyPlot
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\backends\swift
#
#     | copying roboticstoolbox\backends\swift\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\backends\swift
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\bin
#
#     | copying roboticstoolbox\bin\rtbtool.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\bin
#
#     | copying roboticstoolbox\bin\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\bin
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\arm.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\mobile.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\quad_model.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\spatial.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\test.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\uav.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | copying roboticstoolbox\blocks\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\blocks
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\armer.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\aside.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\baur.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\branched_robot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\colors.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\eg2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\eigdemo.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\erobot-test.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\fetch_vision.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\holistic_mm_non_holonomic.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\holistic_mm_omni.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\icra2021.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\ikine_evaluate.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\ikine_evaluate2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\ik_exp.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\ik_speed.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\mexican-wave.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\mmc.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\mobile.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\neo.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\park.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\plot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\plot_swift.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\poly_example.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\puma_fdyn.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\puma_jtraj.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\puma_swift.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\readme.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\robots.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\RRMC.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\RRMC_swift.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\swift_recording.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\teach.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\teach_swift.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\test.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\test1.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\test_et.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\timing.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\tripleangledemo.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\twistdemo.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\vehicle1.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | copying roboticstoolbox\examples\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\examples
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\BaseRobot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\DHFactor.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\DHLink.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\DHRobot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\Dynamics.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\ELink.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\ERobot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\ET.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\ETS.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\Gripper.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\IK.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\Link.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\PoERobot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\Robot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\RobotKinematics.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\RobotProto.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\symsimp.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\symsimp2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\test-plot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\test_fkine.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\test_invdyn.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\timing_dynamics.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | copying roboticstoolbox\robot\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\robot
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\Animations.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\bug.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\Bug2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\CurvaturePolyPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\CurvaturePolyPlanner.py-new.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\DistanceTransformPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\distancexform.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\drivers.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\DstarPlanner-nearly.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\DstarPlanner-old.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\DstarPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\DubinsPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\dubins_path_planning.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\EKF.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\landmarkmap.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\LatticePlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\new.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\OccGrid.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\ParticleFilter.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\PlannerBase.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\plot_vehicle.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\PoseGraph.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\PRMPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\probabilistic_road_map.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\qtiming.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\QuinticPolyPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\reedsshepp-old.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\ReedsSheppPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\rrt.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\RRTPlanner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\rrt_dubins.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\rrt_star.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\rrt_with_pathsmoothing.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\sensors.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\state_lattice_planner.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\test2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\Vehicle.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | copying roboticstoolbox\mobile\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\mobile
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\models
#
#     | copying roboticstoolbox\models\list.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models
#
#     | copying roboticstoolbox\models\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\AL5D.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\arte_parse.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Ball.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Baxter.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Cobra600.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Coil.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Hyper.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Hyper3d.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\IRB140.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Jaco.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\KR5.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\LWR4.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Mico.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Orion5.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\P8.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Panda.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Planar2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Planar3.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Puma560.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Sawyer.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Stanford.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\TwoLink.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\Uprighttl.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\UR10.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\UR3.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\UR5.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | copying roboticstoolbox\models\DH\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\DH
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Frankie.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\GenericSeven.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Omni.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Panda.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Planar2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Planar_Y.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Puma560.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\Puma560dh.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\XYPanda.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | copying roboticstoolbox\models\ETS\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\ETS
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\AL5D.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Fetch.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\FetchCamera.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Frankie.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\FrankieOmni.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\KinovaGen3.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\LBR.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Mico.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Panda.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\PR2.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Puma560.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\px100.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\px150.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\rx150.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\rx200.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\UR10.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\UR3.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\UR5.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\Valkyrie.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\vx300.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\vx300s.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\wx200.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\wx250.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\wx250s.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\YuMi.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | copying roboticstoolbox\models\URDF\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\models\URDF
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\data.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\DHFactor.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\jsingu.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\null.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\numerical.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\params.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\plot.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\p_servo.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\Ticker.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\trajectory.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\types.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | copying roboticstoolbox\tools\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\tools\urdf
#
#     | copying roboticstoolbox\tools\urdf\urdf.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\urdf
#
#     | copying roboticstoolbox\tools\urdf\utils.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\urdf
#
#     | copying roboticstoolbox\tools\urdf\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\urdf
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\tools\xacro
#
#     | copying roboticstoolbox\tools\xacro\cli.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\xacro
#
#     | copying roboticstoolbox\tools\xacro\color.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\xacro
#
#     | copying roboticstoolbox\tools\xacro\xmlutils.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\xacro
#
#     | copying roboticstoolbox\tools\xacro\__init__.py -> build\lib.win-amd64-cpython-311\roboticstoolbox\tools\xacro
#
#     | running egg_info
#
#     | writing roboticstoolbox_python.egg-info\PKG-INFO
#
#     | writing dependency_links to roboticstoolbox_python.egg-info\dependency_links.txt
#
#     | writing entry points to roboticstoolbox_python.egg-info\entry_points.txt
#
#     | writing requirements to roboticstoolbox_python.egg-info\requires.txt
#
#     | writing top-level names to roboticstoolbox_python.egg-info\top_level.txt
#
#     | reading manifest file 'roboticstoolbox_python.egg-info\SOURCES.txt'
#
#     | adding license file 'LICENSE'
#
#     | writing manifest file 'roboticstoolbox_python.egg-info\SOURCES.txt'
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
#     |         You can read more about "package discovery" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#     |
#
#     |         If you don't want 'roboticstoolbox.core' to be distributed and are
#
#     |         already explicitly excluding 'roboticstoolbox.core' via
#
#     |         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#
#     |         you can try to use `exclude_package_data`, or `include-package-data=False` in
#
#     |         combination with a more fine grained `package-data` configuration.
#
#     |
#
#     |         You can read more about "package data files" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#     |
#
#     |
#
#     |         [^1]: For Python, any directory (with suitable naming) can be imported,
#
#     |               even if it does not contain any `.py` files.
#
#     |               On the other hand, currently there is no concept of package data
#
#     |               directory, all directories are treated like packages.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   check.warn(importable)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core.Eigen' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core.Eigen' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core.Eigen' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
#     |         You can read more about "package discovery" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#     |
#
#     |         If you don't want 'roboticstoolbox.core.Eigen' to be distributed and are
#
#     |         already explicitly excluding 'roboticstoolbox.core.Eigen' via
#
#     |         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#
#     |         you can try to use `exclude_package_data`, or `include-package-data=False` in
#
#     |         combination with a more fine grained `package-data` configuration.
#
#     |
#
#     |         You can read more about "package data files" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#     |
#
#     |
#
#     |         [^1]: For Python, any directory (with suitable naming) can be imported,
#
#     |               even if it does not contain any `.py` files.
#
#     |               On the other hand, currently there is no concept of package data
#
#     |               directory, all directories are treated like packages.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   check.warn(importable)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core.Eigen.src.Cholesky' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core.Eigen.src.Cholesky' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core.Eigen.src.Cholesky' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
#     |         You can read more about "package discovery" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#     |
#
#     |         If you don't want 'roboticstoolbox.core.Eigen.src.Cholesky' to be distributed and are
#
#     |         already explicitly excluding 'roboticstoolbox.core.Eigen.src.Cholesky' via
#
#     |         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#
#     |         you can try to use `exclude_package_data`, or `include-package-data=False` in
#
#     |         combination with a more fine grained `package-data` configuration.
#
#     |
#
#     |         You can read more about "package data files" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#     |
#
#     |
#
#     |         [^1]: For Python, any directory (with suitable naming) can be imported,
#
#     |               even if it does not contain any `.py` files.
#
#     |               On the other hand, currently there is no concept of package data
#
#     |               directory, all directories are treated like packages.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   check.warn(importable)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core.Eigen.src.CholmodSupport' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core.Eigen.src.CholmodSupport' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core.Eigen.src.CholmodSupport' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
#     |         You can read more about "package discovery" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#     |
#
#     |         If you don't want 'roboticstoolbox.core.Eigen.src.CholmodSupport' to be distributed and are
#
#     |         already explicitly excluding 'roboticstoolbox.core.Eigen.src.CholmodSupport' via
#
#     |         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#
#     |         you can try to use `exclude_package_data`, or `include-package-data=False` in
#
#     |         combination with a more fine grained `package-data` configuration.
#
#     |
#
#     |         You can read more about "package data files" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#     |
#
#     |
#
#     |         [^1]: For Python, any directory (with suitable naming) can be imported,
#
#     |               even if it does not contain any `.py` files.
#
#     |               On the other hand, currently there is no concept of package data
#
#     |               directory, all directories are treated like packages.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   check.warn(importable)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core.Eigen.src.Core' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core.Eigen.src.Core' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core.Eigen.src.Core' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
#     |         You can read more about "package discovery" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#     |
#
#     |         If you don't want 'roboticstoolbox.core.Eigen.src.Core' to be distributed and are
#
#     |         already explicitly excluding 'roboticstoolbox.core.Eigen.src.Core' via
#
#     |         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#
#     |         you can try to use `exclude_package_data`, or `include-package-data=False` in
#
#     |         combination with a more fine grained `package-data` configuration.
#
#     |
#
#     |         You can read more about "package data files" on setuptools documentation page:
#
#     |
#
#     |         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#     |
#
#     |
#
#     |         [^1]: For Python, any directory (with suitable naming) can be imported,
#
#     |               even if it does not contain any `.py` files.
#
#     |               On the other hand, currently there is no concept of package data
#
#     |               directory, all directories are treated like packages.
#
#     |         ********************************************************************************
#
#     |
#
#     | !!
#
#     |   check.warn(importable)
#
#     | C:\Users\hugol\AppData\Local\Temp\tmpzb481vtf\.venv\Lib\site-packages\setuptools\command\build_py.py:215: _Warning: Package 'roboticstoolbox.core.Eigen.src.Core.arch.AVX' is absent from the `packages` configuration.
#
#     | !!
#
#     |
#
#     |         ********************************************************************************
#
#     |         ############################
#
#     |         # Package would be ignored #
#
#     |         ############################
#
#     |         Python recognizes 'roboticstoolbox.core.Eigen.src.Core.arch.AVX' as an importable package[^1],
#
#     |         but it is absent from setuptools' `packages` configuration.
#
#     |
#
#     |         This leads to an ambiguous overall configuration. If you want to distribute this
#
#     |         package, please make sure that 'roboticstoolbox.core.Eigen.src.Core.arch.AVX' is explicitly added
#
#     |         to the `packages` configuration field.
#
#     |
#
#     |         Alternatively, you can also rely on setuptools' discovery methods
#
#     |         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#
#     |         instead of `find_packages(...)`/`find:`).
#
#     |
#
# ...
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\LU\arch
#
#     | copying roboticstoolbox\core\Eigen\src\LU\arch\InverseSize4.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\LU\arch
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\MetisSupport
#
#     | copying roboticstoolbox\core\Eigen\src\MetisSupport\MetisSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\MetisSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\OrderingMethods
#
#     | copying roboticstoolbox\core\Eigen\src\OrderingMethods\Amd.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\OrderingMethods
#
#     | copying roboticstoolbox\core\Eigen\src\OrderingMethods\Eigen_Colamd.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\OrderingMethods
#
#     | copying roboticstoolbox\core\Eigen\src\OrderingMethods\Ordering.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\OrderingMethods
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\PaStiXSupport
#
#     | copying roboticstoolbox\core\Eigen\src\PaStiXSupport\PaStiXSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\PaStiXSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\PardisoSupport
#
#     | copying roboticstoolbox\core\Eigen\src\PardisoSupport\PardisoSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\PardisoSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\ColPivHouseholderQR.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\ColPivHouseholderQR_LAPACKE.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\CompleteOrthogonalDecomposition.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\FullPivHouseholderQR.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\HouseholderQR.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | copying roboticstoolbox\core\Eigen\src\QR\HouseholderQR_LAPACKE.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\QR
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SPQRSupport
#
#     | copying roboticstoolbox\core\Eigen\src\SPQRSupport\SuiteSparseQRSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SPQRSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | copying roboticstoolbox\core\Eigen\src\SVD\BDCSVD.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | copying roboticstoolbox\core\Eigen\src\SVD\JacobiSVD.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | copying roboticstoolbox\core\Eigen\src\SVD\JacobiSVD_LAPACKE.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | copying roboticstoolbox\core\Eigen\src\SVD\SVDBase.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | copying roboticstoolbox\core\Eigen\src\SVD\UpperBidiagonalization.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SVD
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCholesky
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCholesky\SimplicialCholesky.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCholesky
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCholesky\SimplicialCholesky_impl.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCholesky
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\AmbiVector.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\CompressedStorage.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\ConservativeSparseSparseProduct.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\MappedSparseMatrix.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseAssign.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseBlock.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseColEtree.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseCompressedBase.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseCwiseBinaryOp.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseCwiseUnaryOp.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseDenseProduct.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseDiagonalProduct.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseDot.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseFuzzy.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseMap.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseMatrix.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseMatrixBase.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparsePermutation.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseProduct.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseRedux.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseRef.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseSelfAdjointView.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseSolverBase.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseSparseProductWithPruning.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseTranspose.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseTriangularView.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseUtil.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseVector.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\SparseView.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | copying roboticstoolbox\core\Eigen\src\SparseCore\TriangularSolver.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseCore
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLUImpl.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_Memory.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_Structs.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_SupernodalMatrix.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_Utils.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_column_bmod.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_column_dfs.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_copy_to_ucol.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_gemm_kernel.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_heap_relax_snode.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_kernel_bmod.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_panel_bmod.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_panel_dfs.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_pivotL.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_pruneL.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | copying roboticstoolbox\core\Eigen\src\SparseLU\SparseLU_relax_snode.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseLU
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseQR
#
#     | copying roboticstoolbox\core\Eigen\src\SparseQR\SparseQR.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SparseQR
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\StlSupport
#
#     | copying roboticstoolbox\core\Eigen\src\StlSupport\StdDeque.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\StlSupport
#
#     | copying roboticstoolbox\core\Eigen\src\StlSupport\StdList.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\StlSupport
#
#     | copying roboticstoolbox\core\Eigen\src\StlSupport\StdVector.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\StlSupport
#
#     | copying roboticstoolbox\core\Eigen\src\StlSupport\details.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\StlSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SuperLUSupport
#
#     | copying roboticstoolbox\core\Eigen\src\SuperLUSupport\SuperLUSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\SuperLUSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\UmfPackSupport
#
#     | copying roboticstoolbox\core\Eigen\src\UmfPackSupport\UmfPackSupport.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\UmfPackSupport
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\Image.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\Kernel.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\RealSvd2x2.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\blas.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\lapack.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\lapacke.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | copying roboticstoolbox\core\Eigen\src\misc\lapacke_mangling.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\misc
#
#     | creating build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\ArrayCwiseBinaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\ArrayCwiseUnaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\BlockMethods.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\CommonCwiseBinaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\CommonCwiseUnaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\IndexedViewMethods.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\MatrixCwiseBinaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\MatrixCwiseUnaryOps.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | copying roboticstoolbox\core\Eigen\src\plugins\ReshapedMethods.h -> build\lib.win-amd64-cpython-311\roboticstoolbox\core\Eigen\src\plugins
#
#     | running build_ext
#
#     | building 'roboticstoolbox.frne' extension
#
#     | error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#
# Note: This error originates from the build backend, and is likely not a problem with poetry but one of the following issues with roboticstoolbox-python (1.1.1)
#
#   - not supporting PEP 517 builds
#   - not specifying PEP 517 build requirements correctly
#   - the build requirements are incompatible with your operating system or Python version
#   - the build requirements are missing system dependencies (eg: compilers, libraries, headers).
#
# You can verify this by running pip wheel --no-cache-dir --use-pep517 "roboticstoolbox-python (==1.1.1)".
# Installing C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages\distutils-precedence.pth over existing file

# %% [markdown]
# Inspect the 'pyproject.toml' file in the root folder of the project to see the list of dependencies used in this project. Take also note of the *packages* section, which indicates which folders are considered packages in this project. This allows you to import modules from these folders from anywhere in the project. **If you create new folders that you want to be considered packages, make sure to add them to the *packages* section of the 'pyproject.toml' file and run `poetry install` again.**
#
# If you want to add new dependencies to the project, you can do so by running:
#
# ```bash
# poetry add <package_name>
# ```
#
# The 'poetry.lock' file will be updated automatically to reflect the changes in dependencies.

# %% [markdown]
# ## Verification of installation
#
# Ensure that all the following packages can be imported without any errors (it might take a while for the first time as some packages need to be built):

# %%
# !pip install roboticstoolbox-python==1.1.0 --only-binary :all:
# Out:
# Collecting roboticstoolbox-python==1.1.0
#   Downloading roboticstoolbox_python-1.1.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.4 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.26.4)
# Requirement already satisfied: spatialmath-python>=1.1.5 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.1.15)
# Requirement already satisfied: spatialgeometry>=1.0.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.1.0)
# Requirement already satisfied: pgraph-python in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (0.6.3)
# Requirement already satisfied: scipy in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.15.3)
# Requirement already satisfied: matplotlib in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (3.10.8)
# Requirement already satisfied: ansitable in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (0.11.4)
# Requirement already satisfied: swift-sim>=1.0.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.1.0)
# Requirement already satisfied: rtb-data in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.0.1)
# Requirement already satisfied: progress in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (1.6.1)
# Requirement already satisfied: typing-extensions in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from roboticstoolbox-python==1.1.0) (4.15.0)
# Requirement already satisfied: pre-commit in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (4.5.1)
# Requirement already satisfied: websockets in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from swift-sim>=1.0.0->roboticstoolbox-python==1.1.0) (10.4)
# Requirement already satisfied: colored in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from ansitable->roboticstoolbox-python==1.1.0) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from matplotlib->roboticstoolbox-python==1.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from python-dateutil>=2.7->matplotlib->roboticstoolbox-python==1.1.0) (1.17.0)
# Requirement already satisfied: cfgv>=2.0.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (1.10.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (20.36.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.20.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (3.20.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python==1.1.0) (4.5.1)
# Downloading roboticstoolbox_python-1.1.0-cp311-cp311-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/1.9 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 5.3 MB/s  0:00:00
# Installing collected packages: roboticstoolbox-python
# Successfully installed roboticstoolbox-python-1.1.0

# %%
# !pip install "scipy<1.11"
# Out:
# Collecting scipy<1.11
#   Downloading scipy-1.10.1-cp311-cp311-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages (from scipy<1.11) (1.26.4)
# Downloading scipy-1.10.1-cp311-cp311-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    ------- -------------------------------- 7.6/42.2 MB 42.7 MB/s eta 0:00:01
#    --------------- ------------------------ 16.5/42.2 MB 41.6 MB/s eta 0:00:01
#    ------------------------ --------------- 25.7/42.2 MB 41.7 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 42.2 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 35.8 MB/s  0:00:01
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# Successfully installed scipy-1.10.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hugol\miniconda3\envs\python311\Lib\site-packages\~cipy'.
#   You can safely remove it manually.

# %%
import numpy
import roboticstoolbox
import spatialmath
import matplotlib
import pandas

# %% [markdown]
# Ensure that all the following packages can be imported without any errors:

# %%
import sys
import os

# On remonte d'un cran (ou plus) pour atteindre la racine du projet
# Si ton notebook est dans un sous-dossier, utilise os.path.abspath('..')
project_root = os.path.abspath('..') 
if project_root not in sys.path:
    sys.path.append(project_root)

# Maintenant l'import devrait fonctionner
from communication.protocol import CtrlMsgFields
print("Modules locaux chargés avec succès !")
# Out:
# Modules locaux chargés avec succès !

# %% [markdown]
# Now you're ready to start working on the project!
